# %%
import rioxarray 
import xarray as xr
import matplotlib.pyplot as plt

# %%
# Load the NetCDF file using xarray
xds = xr.open_dataset(r"C:\Users\bsf31\Documents\post-meds\data\signal\EEMS_Online_Model_Results_QlvBOBzadbQ9hXLR584QuRxKY5c6FyXd\data\results.nc", decode_coords="all")

# Set the CRS using rio.write_crs() for each data variable
for var in xds.data_vars:
    xds[var].rio.write_crs("EPSG:4326", inplace=True)

# %%
# Select a variable for visualization
variable_name = 'Available_Space'  # Replace with your chosen variable

# Visualize the data
xds[variable_name].plot()
plt.show()

# %%
# Load the NetCDF file using xarray
xds = xr.open_dataset(r"C:\Users\bsf31\Documents\post-meds\data\signal\EEMS_Online_Model_Results_QlvBOBzadbQ9hXLR584QuRxKY5c6FyXd\data\results.nc", decode_coords="all")

# Set the CRS for each data variable if needed
for var in xds.data_vars:
    xds[var].rio.set_spatial_dims(x_dim="x", y_dim="y", inplace=True)
    xds.sortby(["x", "y"])
    xds[var].rio.write_crs("EPSG:32610", inplace=True)

# %%
# Select a variable for visualization
variable_name = 'Available_Space'  # Replace with your chosen variable

# Visualize the data
xds[variable_name].plot()
plt.show()
plt.interactive()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       5 xds[variable_name].plot()
#       6 plt.show()
# ----> 7 plt.interactive()
#
# TypeError: interactive() missing 1 required positional argument: 'b'

# %%
xds['Available_Space'].rio.to_raster(r'C:\Users\bsf31\Documents\post-meds\data\signal\testnc.tif')

# %%
nc = rioxarray.open_rasterio(r'C:\Users\bsf31\Documents\post-meds\data\signal\EEMS_Online_Model_Results_QlvBOBzadbQ9hXLR584QuRxKY5c6FyXd\data\results.nc')
# Out:
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rasterio\__init__.py:319: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\_io.py:1132: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore

# %%
nc

# %%
print(nc.dims)
print(nc.attrs)
print(nc.coords)

# %%
# Set the CRS for each data variable if needed
for var in nc.data_vars:
    nc[var].rio.set_spatial_dims(x_dim="x", y_dim="y", inplace=True)
    nc[var].rio.write_crs("EPSG:4326", inplace=True)

# %%
nc.rio.to_raster(r'C:\Users\bsf31\Documents\post-meds\data\signal\testnc.tif')
# Out:
# ---------------------------------------------------------------------------
# RioXarrayError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 nc.rio.to_raster(r'C:\Users\bsf31\Documents\post-meds\data\signal\testnc.tif')
#
# File c:\ProgramData\Anaconda3\envs\usra\Lib\site-packages\rioxarray\raster_dataset.py:529, in RasterDataset.to_raster(self, raster_path, driver, dtype, tags, windowed, recalc_transform, lock, compute, **profile_kwargs)
#     527     data_array.rio.write_nodata(nodata, inplace=True)
#     528 else:
# --> 529     raise RioXarrayError(
#     530         "All nodata values must be the same when exporting to raster. "
#     531         f"Current values: {nodatavals}"
#     532     )
#     533 if self.crs is not None:
#     534     data_array.rio.write_crs(self.crs, inplace=True)
#
# RioXarrayError: All nodata values must be the same when exporting to raster. Current values: [1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 999999, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20, 1e+20]

# %%
nc['Available_Space'].plot()
plt.show()
